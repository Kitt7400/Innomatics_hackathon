# %%
import pandas as pd
import sqlite3
import json

# %%
orders = pd.read_csv('order.csv')
orders.head()
# Out:
#    order_id  user_id  restaurant_id  order_date  total_amount  \
# 0         1     2508            450  18-02-2023        842.97
# 1         2     2693            309  18-01-2023        546.68
# 2         3     2084            107  15-07-2023        163.93
# 3         4      319            224  04-10-2023       1155.97
# 4         5     1064            293  25-12-2023       1321.91
#
#                   restaurant_name
# 0               New Foods Chinese
# 1  Ruchi Curry House Multicuisine
# 2           Spice Kitchen Punjabi
# 3          Darbar Kitchen Non-Veg
# 4       Royal Eatery South Indian

# %%
users = pd.read_json('users.json')
users.head()
# Out:
#    user_id    name       city membership
# 0        1  User_1    Chennai    Regular
# 1        2  User_2       Pune       Gold
# 2        3  User_3  Bangalore       Gold
# 3        4  User_4  Bangalore    Regular
# 4        5  User_5       Pune       Gold

# %%
with open('restaurants.sql', 'r') as f:
    sql_script = f.read()

conn = sqlite3.connect(":memory:")
conn.executescript(sql_script)

restaurants = pd.read_sql_query("SELECT * FROM restaurants", conn)
restaurants.head()
# Out:
#    restaurant_id restaurant_name  cuisine  rating
# 0              1    Restaurant_1  Chinese     4.8
# 1              2    Restaurant_2   Indian     4.1
# 2              3    Restaurant_3  Mexican     4.3
# 3              4    Restaurant_4  Chinese     4.1
# 4              5    Restaurant_5  Chinese     4.8

# %%
orders.columns = orders.columns.str.lower()
users.columns = users.columns.str.lower()
restaurants.columns = restaurants.columns.str.lower()

# %%
df = orders.merge(users, how='left', on='user_id')
df = df.merge(restaurants, how='left', on='restaurant_id')

df.head(40)
# Out:
#     order_id  user_id  restaurant_id  order_date  total_amount  \
# 0          1     2508            450  18-02-2023        842.97
# 1          2     2693            309  18-01-2023        546.68
# 2          3     2084            107  15-07-2023        163.93
# 3          4      319            224  04-10-2023       1155.97
# 4          5     1064            293  25-12-2023       1321.91
# 5          6     2933            499  12-07-2023       1497.22
# 6          7      970             35  30-05-2023        129.21
# 7          8      891             57  07-11-2023        269.19
# 8          9      364              7  05-12-2023        953.30
# 9         10     2972            183  30-12-2023        351.41
# 10        11      924            235  10-12-2023        523.82
# 11        12      884            423  27-10-2023       1484.65
# 12        13     1958            244  11-08-2023        216.59
# 13        14      364            112  24-09-2023        898.24
# 14        15     1733            383  17-07-2023       1098.41
# 15        16     1321            149  17-07-2023        475.74
# 16        17     1896            421  09-04-2023       1002.51
# 17        18     1617            414  23-04-2023        736.89
# 18        19      330             73  27-12-2023        392.59
# 19        20     2567             52  03-02-2023        362.01
# 20        21     1610            186  13-08-2023        743.68
# 21        22      688            279  12-07-2023        507.82
# 22        23     2640             83  14-06-2023       1025.36
# 23        24     2403            434  22-01-2023        412.50
# 24        25      288             18  07-06-2023        147.90
# 25        26     2915            129  24-12-2023        933.31
# 26        27     1056            399  08-08-2023        678.38
# 27        28     2370             63  23-03-2023        900.74
# 28        29     2905            115  20-09-2023        903.00
# 29        30     2009             18  23-04-2023        996.26
# 30        31     1986            190  03-04-2023        199.16
# 31        32     1407             93  26-01-2023        741.10
# 32        33     1761            346  04-07-2023        957.07
# 33        34      844            350  15-06-2023        455.96
# 34        35     2858            291  15-05-2023        121.81
# 35        36      186            113  12-09-2023        140.83
# 36        37      952             34  01-02-2023       1198.64
# 37        38     2972            376  11-01-2023        751.82
# 38        39      118            170  23-02-2023        596.06
# 39        40     2773             63  25-07-2023        622.50
#
#                       restaurant_name_x       name       city membership  \
# 0                     New Foods Chinese  User_2508  Hyderabad    Regular
# 1        Ruchi Curry House Multicuisine  User_2693       Pune    Regular
# 2                 Spice Kitchen Punjabi  User_2084    Chennai       Gold
# 3                Darbar Kitchen Non-Veg   User_319  Bangalore       Gold
# 4             Royal Eatery South Indian  User_1064       Pune    Regular
# 5        Annapurna Tiffins South Indian  User_2933    Chennai    Regular
# 6            Royal Biryani North Indian   User_970  Bangalore    Regular
# 7                    Spice Mess Punjabi   User_891       Pune    Regular
# 8                 Ruchi Biryani Punjabi   User_364    Chennai       Gold
# 9              Taste of Biryani Non-Veg  User_2972  Bangalore    Regular
# 10      Amma Delights Family Restaurant   User_924    Chennai    Regular
# 11           Royal Tiffins Multicuisine   User_884       Pune       Gold
# 12            Amma Tiffins South Indian  User_1958    Chennai    Regular
# 13                   Grand Cafe Punjabi   User_364    Chennai       Gold
# 14            Amma Biryani North Indian  User_1733       Pune    Regular
# 15         Amma Restaurant South Indian  User_1321       Pune       Gold
# 16                  Ruchi Foods Chinese  User_1896       Pune    Regular
# 17         Darbar Delights South Indian  User_1617       Pune       Gold
# 18                    Spice Mess Andhra   User_330    Chennai    Regular
# 19       Udupi Curry House South Indian  User_2567  Bangalore       Gold
# 20       Darbar Restaurant North Indian  User_1610       Pune    Regular
# 21                   Sri Tiffins Andhra   User_688  Hyderabad       Gold
# 22                 Darbar Mess Pure Veg  User_2640  Bangalore       Gold
# 23                 Amma Kitchen Punjabi  User_2403       Pune       Gold
# 24  Annapurna Kitchen Family Restaurant   User_288       Pune    Regular
# 25                New Cafe North Indian  User_2915    Chennai       Gold
# 26            Swagath Cafe Multicuisine  User_1056  Bangalore    Regular
# 27             Ruchi Foods South Indian  User_2370  Bangalore    Regular
# 28             Annapurna Eatery Non-Veg  User_2905       Pune       Gold
# 29  Annapurna Kitchen Family Restaurant  User_2009    Chennai       Gold
# 30             Amma Restaurant Pure Veg  User_1986  Bangalore    Regular
# 31            Swagath Cafe Multicuisine  User_1407       Pune       Gold
# 32                   Amma Dhaba Non-Veg  User_1761  Bangalore       Gold
# 33     Classic Curry House South Indian   User_844    Chennai       Gold
# 34              Annapurna Foods Non-Veg  User_2858  Hyderabad    Regular
# 35              Darbar Biryani Pure Veg   User_186    Chennai    Regular
# 36             Ruchi Dhaba Multicuisine   User_952    Chennai       Gold
# 37                    Amma Cafe Non-Veg  User_2972  Bangalore    Regular
# 38      Spice Tiffins Family Restaurant   User_118       Pune    Regular
# 39             Ruchi Foods South Indian  User_2773       Pune       Gold
#
#    restaurant_name_y  cuisine  rating
# 0     Restaurant_450  Mexican     3.2
# 1     Restaurant_309   Indian     4.5
# 2     Restaurant_107  Mexican     4.0
# 3     Restaurant_224  Chinese     4.8
# 4     Restaurant_293  Italian     3.0
# 5     Restaurant_499  Mexican     4.9
# 6      Restaurant_35  Chinese     3.9
# 7      Restaurant_57  Mexican     4.4
# 8       Restaurant_7  Italian     3.2
# 9     Restaurant_183  Chinese     3.7
# 10    Restaurant_235  Italian     4.5
# 11    Restaurant_423   Indian     3.2
# 12    Restaurant_244  Italian     4.3
# 13    Restaurant_112  Chinese     3.2
# 14    Restaurant_383   Indian     3.1
# 15    Restaurant_149  Mexican     3.6
# 16    Restaurant_421   Indian     3.0
# 17    Restaurant_414  Chinese     4.7
# 18     Restaurant_73  Mexican     3.1
# 19     Restaurant_52  Mexican     4.9
# 20    Restaurant_186   Indian     4.3
# 21    Restaurant_279  Italian     4.9
# 22     Restaurant_83  Chinese     3.5
# 23    Restaurant_434  Italian     4.7
# 24     Restaurant_18  Italian     4.5
# 25    Restaurant_129   Indian     4.1
# 26    Restaurant_399  Chinese     3.2
# 27     Restaurant_63  Italian     5.0
# 28    Restaurant_115  Chinese     3.3
# 29     Restaurant_18  Italian     4.5
# 30    Restaurant_190  Chinese     3.1
# 31     Restaurant_93  Chinese     4.9
# 32    Restaurant_346   Indian     4.5
# 33    Restaurant_350  Mexican     3.2
# 34    Restaurant_291  Mexican     4.3
# 35    Restaurant_113  Chinese     5.0
# 36     Restaurant_34  Chinese     4.3
# 37    Restaurant_376   Indian     3.4
# 38    Restaurant_170  Mexican     4.4
# 39     Restaurant_63  Italian     5.0

# %%
df['order_date'] = pd.to_datetime(df['order_date'], dayfirst=True)

# %%
#Which city has the highest total revenue (total_amount) from Gold members?
df[df['membership']=='Gold'].groupby('city')['total_amount'].sum().sort_values(ascending=False)
# Out:
# city
# Chennai      1080909.79
# Pune         1003012.32
# Bangalore     994702.59
# Hyderabad     896740.19
# Name: total_amount, dtype: float64

# %%
#Which cuisine has the highest average order value across all orders?
df.groupby('cuisine')['total_amount'].mean().sort_values(ascending=False)
# Out:
# cuisine
# Mexican    808.021344
# Italian    799.448578
# Indian     798.466011
# Chinese    798.389020
# Name: total_amount, dtype: float64

# %%
#How many distinct users placed orders worth more than ₹1000 in total (sum of all their orders)?
user_spend = df.groupby('user_id')['total_amount'].sum()
(user_spend > 1000).sum()
# Out:
# np.int64(2544)

# %%
#Which restaurant rating range generated the highest total revenue?
bins = [3.0, 3.5, 4.0, 4.5, 5.0]
labels = ["3.0–3.5", "3.6–4.0", "4.1–4.5", "4.6–5.0"]

df['rating_range'] = pd.cut(df['rating'], bins=bins, labels=labels, include_lowest=True)

df.groupby('rating_range', observed=False)['total_amount'].sum().sort_values(ascending=False)
# Out:
# rating_range
# 4.6–5.0    2197030.75
# 3.0–3.5    2136772.70
# 4.1–4.5    1960326.26
# 3.6–4.0    1717494.41
# Name: total_amount, dtype: float64

# %%
#Among Gold members, which city has the highest average order value?
df[df['membership']=='Gold'].groupby('city')['total_amount'].mean().sort_values(ascending=False)
# Out:
# city
# Chennai      808.459080
# Hyderabad    806.421034
# Bangalore    793.223756
# Pune         781.162243
# Name: total_amount, dtype: float64

# %%
#Which cuisine has the lowest number of distinct restaurants but still contributes significant revenue?
# Number of restaurants per cuisine
restaurants.groupby('cuisine')['restaurant_id'].nunique().sort_values()

# Revenue per cuisine
df.groupby('cuisine')['total_amount'].sum().sort_values(ascending=False)
# Out:
# cuisine
# Mexican    2085503.09
# Italian    2024203.80
# Indian     1971412.58
# Chinese    1930504.65
# Name: total_amount, dtype: float64

# %%
#What percentage of total orders were placed by Gold members? (Rounded to nearest integer)
round((df[df['membership']=='Gold'].shape[0] / df.shape[0]) * 100)
# Out:
# 50

# %%
df[df['restaurant_name_y'] == 'Restaurant_294'][
    ['restaurant_name_x', 'cuisine', 'rating', 'total_amount']
].head()
# Out:
#              restaurant_name_x  cuisine  rating  total_amount
# 1407  Hotel Dhaba Multicuisine  Italian     3.1        817.71
# 1643  Hotel Dhaba Multicuisine  Italian     3.1       1327.91
# 2426  Hotel Dhaba Multicuisine  Italian     3.1        629.97
# 3174  Hotel Dhaba Multicuisine  Italian     3.1       1004.28
# 3243  Hotel Dhaba Multicuisine  Italian     3.1       1189.93

# %%
#Which combination contributes the highest revenue?

df.groupby(['membership','cuisine'])['total_amount'].sum().sort_values(ascending=False)
# Out:
# membership  cuisine
# Regular     Mexican    1072943.30
#             Italian    1018424.75
# Gold        Mexican    1012559.79
#             Italian    1005779.05
# Regular     Indian      992100.27
# Gold        Indian      979312.31
#             Chinese     977713.74
# Regular     Chinese     952790.91
# Name: total_amount, dtype: float64

# %%
#During which quarter of the year is the total revenue highest?
df['order_date'] = pd.to_datetime(df['order_date'], dayfirst=True)
df['quarter'] = df['order_date'].dt.quarter

df.groupby('quarter')['total_amount'].sum().sort_values(ascending=False)
# Out:
# quarter
# 3    2037385.10
# 4    2018263.66
# 1    2010626.64
# 2    1945348.72
# Name: total_amount, dtype: float64

# %%
#How many total orders were placed by users with Gold membership?
df[df['membership'] == 'Gold'].shape[0]
# Out:
# 4987

# %%
#What is the total revenue (rounded to nearest integer) generated from orders placed in Hyderabad city?
round(df[df['city'] == 'Hyderabad']['total_amount'].sum())
# Out:
# 1889367

# %%
#How many distinct users placed at least one order?
df['user_id'].nunique()
# Out:
# 2883

# %%
#What is the average order value (rounded to 2 decimals) for Gold members?
round(df[df['membership'] == 'Gold']['total_amount'].mean(), 2)
# Out:
# np.float64(797.15)

# %%
#How many orders were placed for restaurants with rating ≥ 4.5?
df[df['rating'] >= 4.5].shape[0]
# Out:
# 3374

# %%
#How many orders were placed in the top revenue city among Gold members only?
df[(df['membership'] == 'Gold') & (df['city'] == 'Chennai')].shape[0]
# Out:
# 1337
